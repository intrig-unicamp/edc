# %%
import matplotlib.pyplot as plt
#plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib

# %%
case = pd.read_csv("cases/Driving-8.csv")

# %%
case.columns
# Out:
# Index(['no', 'value'], dtype='object')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(case['no'], case['value'],  color='blue', alpha=0.8)

plt.grid(True)
plt.ylabel("5G QoS bandwidth in Mbps")
plt.xlabel("4s Interval")
plt.savefig('driving-8.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
df = pd.read_csv("5s-allvideos - Sheet1.csv")

# %%
df.columns
# Out:
# Index(['Video', 'Window', 'ExpID', 'Case', 'Algo', 'timeslot sec',
#        'timeslot mil', 'IAT', 'IPG Avg', 'IPG Avg GT100', 'IAT GT100',
#        'Throughput', 'Total Packets', 'Total Packet GT100', '10p Length',
#        '20p Length', '30p Length', '40p Length', '50p Length', '60p Length',
#        '70p Length', '80p Length', '90p Length', 'Single EMA', 'CUSUM',
#        'Double EMA', 'P1203', 'P1203C', 'P1203N'],
#       dtype='object')

# %%
b=df[(df['ExpID']==1)]
s=df[(df['ExpID']==10)]
t=df[(df['ExpID']==20)]

b_9=df[(df['ExpID']==3)]
s_9=df[(df['ExpID']==13)]
t_9=df[(df['ExpID']==21)]

b_8=df[(df['ExpID']==5)]
s_8=df[(df['ExpID']==15)]
t_8=df[(df['ExpID']==23)]

# %%
t.shape[0]
# Out:
# 47

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b['timeslot sec'], b['Throughput'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s['timeslot sec'], s['Throughput'],  color='red', label='Sintel',marker='x')
plt.plot(t['timeslot sec'], t['Throughput'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Throughput")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/throughput-10.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_9['timeslot sec'], b_9['Throughput'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_9['timeslot sec'], s_9['Throughput'],  color='red', label='Sintel',marker='x')
plt.plot(t_9['timeslot sec'], t_9['Throughput'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Throughput")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/throughput-9.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_8['timeslot sec'], b_8['Throughput'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_8['timeslot sec'], s_8['Throughput'],  color='red', label='Sintel',marker='x')
plt.plot(t_8['timeslot sec'], t_8['Throughput'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Throughput")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/throughput-8.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b['timeslot sec'], b['P1203'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s['timeslot sec'], s['P1203'],  color='red', label='Sintel',marker='x')
plt.plot(t['timeslot sec'], t['P1203'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("P.1203")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/p1203-10.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b['timeslot sec'], b['CUSUM'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s['timeslot sec'], s['CUSUM'],  color='red', label='Sintel',marker='x')
plt.plot(t['timeslot sec'], t['CUSUM'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("CUSUM")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/cusum-10.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_9['timeslot sec'], b_9['CUSUM'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_9['timeslot sec'], s_9['CUSUM'],  color='red', label='Sintel',marker='x')
plt.plot(t_9['timeslot sec'], t_9['CUSUM'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("CUSUM")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/cusum-9.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_8['timeslot sec'], b_8['CUSUM'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_8['timeslot sec'], s_8['CUSUM'],  color='red', label='Sintel',marker='x')
plt.plot(t_8['timeslot sec'], t_8['CUSUM'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("CUSUM")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/cusum-8.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b['timeslot sec'], b['Double EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s['timeslot sec'], s['Double EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t['timeslot sec'], t['Double EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Double EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/dema-10.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_9['timeslot sec'], b_9['Double EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_9['timeslot sec'], s_9['Double EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t_9['timeslot sec'], t_9['Double EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Double EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/dema-9.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_8['timeslot sec'], b_8['Double EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_8['timeslot sec'], s_8['Double EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t_8['timeslot sec'], t_8['Double EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Double EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/dema-8.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b['timeslot sec'], b['Single EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s['timeslot sec'], s['Single EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t['timeslot sec'], t['Single EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Single EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/ema-10.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_9['timeslot sec'], b_9['Single EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_9['timeslot sec'], s_9['Single EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t_9['timeslot sec'], t_9['Single EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Single EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/ema-9.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(b_8['timeslot sec'], b_8['Single EMA'],  color='blue', label='Bigbuckbunny',marker='D')
plt.plot(s_8['timeslot sec'], s_8['Single EMA'],  color='red', label='Sintel',marker='x')
plt.plot(t_8['timeslot sec'], t_8['Single EMA'],  color='green', label='Tears of Steel',marker='o')
plt.grid(True)
plt.ylabel("Single EMA")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")
plt.savefig('results/ema-8.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
logs = pd.read_csv("5s-allvideos - Sheet2.csv")

# %%
logs.columns
# Out:
# Index(['intExpID', 'Type', 'Case', 'Protocol', 'total_users', 'user_no',
#        'intSeg', 'intArr', 'intDel', 'intSta', 'intRep', 'intDelRate',
#        'intActRate', 'intByteSize', 'floatBuf', 'algorithm_used', 'seg_Dur',
#        'width', 'height', 'resolutions', 'Clae', 'Duanmu', 'Yin', 'Yu',
#        'P1203'],
#       dtype='object')

# %%
bl=logs[(logs['intExpID']==1)]
sl=logs[(logs['intExpID']==10)]
tl=logs[(logs['intExpID']==20)]

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.plot(bl['intSeg'], bl['intSta'],  color='blue', label='Bigbuckbunny')
plt.plot(sl['intSeg'], sl['intSta'],  color='red', label='Sintel')
plt.plot(tl['intSeg'], tl['intSta'],  color='green', label='Tears of Steel')
plt.grid(True)
plt.ylabel("P.1203")
plt.xlabel("Segments (2s) of four minutes stream")
plt.legend(loc="upper center")

# %%
combined = pd.read_csv("5s-allvideos - Sheet1.csv")

# %%
combined.columns
# Out:
# Index(['Video', 'Window', 'ExpID', 'Case', 'Algo', 'timeslot sec',
#        'timeslot mil', 'IAT', 'IPG Avg', 'IPG Avg GT100', 'IAT GT100',
#        'Throughput', 'Total Packets', 'Total Packet GT100', '10p Length',
#        '20p Length', '30p Length', '40p Length', '50p Length', '60p Length',
#        '70p Length', '80p Length', '90p Length', 'Single EMA', 'CUSUM',
#        'Double EMA', 'P1203', 'P1203C', 'P1203N'],
#       dtype='object')

# %%
ball=combined[(combined['Video']=='bigbuckbunny') & (combined['Case']=='Driving-10')]
sall=combined[(combined['Video']=='sintel') & (combined['Case']=='Driving-10')]
tall=combined[(combined['Video']=='tears') & (combined['Case']=='Driving-10')]


ball_9=combined[(combined['Video']=='bigbuckbunny') & (combined['Case']=='Driving-9')]
sall_9=combined[(combined['Video']=='sintel') & (combined['Case']=='Driving-9')]
tall_9=combined[(combined['Video']=='tears') & (combined['Case']=='Driving-9')]

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['CUSUM'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['CUSUM'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['CUSUM'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("CUSUM")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/cusum-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['Double EMA'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['Double EMA'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['Double EMA'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Double EMA")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/dema-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['Total Packets'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['Total Packets'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['Total Packets'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Total Packets")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/packets-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['Throughput'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['Throughput'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['Throughput'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Throughput")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/throughput-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['P1203'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['P1203'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['P1203'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("P.1203")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/P1203-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['Single EMA'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['Single EMA'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['Single EMA'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("EMA")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/ema-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball['timeslot sec'], ball['Total Packet GT100'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall['timeslot sec'], sall['Total Packet GT100'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall['timeslot sec'], tall['Total Packet GT100'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Total Packet GT100")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/gt100-case-10-all.pdf', format='pdf' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball_9['timeslot sec'], ball_9['Throughput'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall_9['timeslot sec'], sall_9['Throughput'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall_9['timeslot sec'], tall_9['Throughput'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Throughput")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/throughput-case-9-all.png', format='png' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball_9['timeslot sec'], ball_9['CUSUM'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall_9['timeslot sec'], sall_9['CUSUM'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall_9['timeslot sec'], tall_9['CUSUM'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Throughput")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/CUSUM-case-9-all.png', format='png' ,bbox_inches = 'tight')

# %%
matplotlib.rc('axes',edgecolor='#D3D3D3')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.scatter(ball_9['timeslot sec'], ball_9['Double EMA'],  color='blue',  marker='D', label='Bigbuckbunny')
plt.scatter(sall_9['timeslot sec'], sall_9['Double EMA'],  color='red',   marker='x', label='Sintel')
plt.scatter(tall_9['timeslot sec'], tall_9['Double EMA'],  color='green',   marker='o', label='Tears of Steel')
# plt.title('Number of Packets vs. IPG')
plt.xlabel("Video session 4-minutes")
plt.ylabel("Throughput")
plt.grid(True)
plt.legend(loc="upper center")
plt.savefig('results/dema-case-9-all.png', format='png' ,bbox_inches = 'tight')

# %%
voilin = pd.read_csv("5s-allvideos - Sheet1.csv")

# %%
vl =voilin[(voilin['Case']=='Driving-9')]

# %%
vl['Video'] = vl.Video.str.capitalize()
# Out:
# <ipython-input-121-8a7102b1497b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vl['Video'] = vl.Video.str.capitalize()

# %%
vl.columns
# Out:
# Index(['Video', 'Window', 'ExpID', 'Case', 'Algo', 'timeslot sec',
#        'timeslot mil', 'IAT', 'IPG Avg', 'IPG Avg GT100', 'IAT GT100',
#        'Throughput', 'Total Packets', 'Total Packet GT100', '10p Length',
#        '20p Length', '30p Length', '40p Length', '50p Length', '60p Length',
#        '70p Length', '80p Length', '90p Length', 'Single EMA', 'CUSUM',
#        'Double EMA', 'P1203', 'P1203C', 'P1203N'],
#       dtype='object')

# %%
sns.catplot(data=vl, kind="violin", x="Video", y="CUSUM", split=True)
plt.xlabel("Video session 4-minutes")
plt.ylabel("Throughput in BPS")
plt.grid(True)
# plt.legend(loc="upper center")

# %%
streaming_time = n_minutes
current_time = 0
step = 5s
array_length = array()
array_packets_time = array()
while (current_time<n_minutes) do
